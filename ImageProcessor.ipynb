# %% [markdown]
# Image Processing

# %%
import glob
import PIL.Image
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.image as mpimg
import matplotlib.patches as patches
from IPython.core.debugger import Tracer
import cv2

# %%
class Constants:
    # The paths below recently changed.. so be sure to consider that...
    orig_images_root = "/home/apil/data/hw_forms/initial_data/s3_upload1/"
    labels_path = "/home/apil/data/hw_forms/initial_data/labels.csv"
    labels_renamed_path = "/home/apil/data/hw_forms/initial_data/labels_renamed.csv"
    masks_root = "/home/apil/data/hw_forms/train/masks/"
    greyscale_root = "/home/apil/data/hw_forms/train/images/"

# %%
'''
Run the following so that all files are changed to have .jpg format:
----------------------------
for f in *.jpeg; do 
mv -- "$f" "${f%.jpeg}.jpg"
done
----------------------------
for f in *.png; do 
mv -- "$f" "${f%.png}.jpg"
done
----------------------------
for f in *.JPG; do 
mv -- "$f" "${f%.JPG}.jpg"
done
'''
pass

# %%
'''
Run the following so that file references in labels.csv are changed 
so that all images are referenced with their .jpg extensions
'''

"""
def modifyLabels():
    counter = 0;
    g = open(Constants.labels_renamed_path, "w")
    with open(Constants.labels_path) as f:
        for line in f:
            line = line.replace(".jpeg", ".jpg")
            line = line.replace(".png", ".jpg")
            line = line.replace(".JPG",".jpg")
            counter +=1
            g.write(line)
    print("wrote {:d} lines.".format(counter))
"""

'''
Run the below to modify the labels, so that all images
with .jpeg, .png, .JPG files are renamed aptly to .jpg
----------------------------
modifyLabels()
----------------------------
'''
pass

# %%
class FormImage:

    def __init__(self, name, boxes):
        self.name = name
        self.boxes = boxes

# %%
class Box:  
    
    def __init__(self, tL, tR, bL, bR):
        
        self.x0 = tL
        self.y0 = tR
        
        self.x1 = bL
        self.y1 = tR
        
        self.x2 = bL
        self.y2 = bR
        
        self.x3 = tL
        self.y3 = bR
    
    def toStr(self):
        return " tL: ({:d},{:d}), tR: ({:d},{:d}), bR: ({:d},{:d}), bL: ({:d},{:d}) ".format( \
                                            self.x0, self.y0, self.x1, self.y1, self.x2, self.y2, self.x3, self.y3)

    def evalPatchParams(self, orig_ht, resize_ht, orig_wd, resize_wd):
        box_ht = self.y2 - self.y1
        box_wd = self.x2 - self.x0
        
        print("box corners: {}".format(self.toStr()))
        print("box ht: {}, box wd: {}".format(box_ht, box_wd))
        print("orig_ht: {}, orig_wd: {}, resize_ht: {}, resize_wd: {}".format(orig_ht, orig_wd, resize_ht, resize_wd))
        
        ht_rescale = resize_ht/orig_ht 
        wd_rescale = resize_wd/orig_wd 

        new_x0 = self.x0 * wd_rescale
        new_y0 = self.y0 * ht_rescale

        new_ht = box_ht * ht_rescale
        new_wd = box_wd * wd_rescale
        
        return (new_x0, new_y0), new_wd, new_ht

    @classmethod
    def fromStr(cls, string, imgName):
        temp = [val.strip() for val in string.split(',')]
        try:
            return cls(Box.num(temp[0]), Box.num(temp[1]), Box.num(temp[2]), Box.num(temp[3]))
        except ValueError as e:            
            # print("failed to parse to int. Passed string is: {}, ImageName is: {}".format(string, imgName))
            pass
            
    
    @staticmethod
    def num(s):
        try:
            return int(s)
        except:
            # print("ERROR trying to parse int from string: {}".format(s))
            raise ValueError("ERROR trying to parse int from string: {}".format(s))

# %%
class Utils:
    
    @staticmethod
    def extractName(line):
        imgName = line[line.rfind('/')+1 : line.rfind('.jpg')]
        return imgName
    
    @staticmethod
    def extractCoords(line):
        coords = line[line.rfind('.jpg,')+5 : line.rfind(',qr')]
        return coords

# %%
class AllImages:
    
    def __init__(self):
        self.initFromLabels();
    
    def add(self, formImage):
        formImages.append(formImage)
    
    def initFromLabels(self):
        self.imageToBoxes = {}
        with open(Constants.labels_renamed_path) as f:
            for line in f:
                imgName = Utils.extractName(line)
                coords = Utils.extractCoords(line)
                
                box = Box.fromStr(coords, imgName)                                       
                imgBoxes = self.imageToBoxes.get(imgName, [])
                imgBoxes.append(box)
                self.imageToBoxes[imgName] = imgBoxes
                
    def getBoxes(self, imgName):
        return self.imageToBoxes.get(imgName,[])

# %%
def createMask(cv2Img, imgName, boxes):
    ht, wd = cv2Img.shape
    arr = np.zeros((ht, wd), dtype=np.uint8)
    for box in boxes:
        arr[box.y0: box.y3+1, box.x0: box.x1+1] = 255

    destImg = Constants.masks_root + imgName + ".jpg"        
    im2 = cv2.imwrite(destImg, arr)

# %%
def displayImage(imgPath):
    img=mpimg.imread(imgPath)
    imgplot = plt.imshow(img)
    plt.show()

# %%
class ImageProcessor:

    def __init__(self):
        self.allImages = AllImages()
        
    def processImages(self):
        cntGood = 0
        cntBad = 0
        
        for infile in glob.glob(Constants.orig_images_root + "/*.jpg"):

            try:
                imgName = Utils.extractName(infile)
                boxes = self.allImages.getBoxes(imgName)

                # do not process image if no qr codes found.
                if(boxes is None or len(boxes) == 0):
                    cntBad +=1
                    print("skipping image: {} because ZERO boxes were found".format(imgName))
                    print("----------------------------------") 
                    continue

                outfile = Constants.greyscale_root +imgName+".jpg"


                print("processing file: {}".format(infile))   
                print("boxes found: {}".format(len(boxes)))
                im = cv2.imread(infile, cv2.IMREAD_GRAYSCALE)

                # Create a mask of the image... and save it. The height and width of
                # the mask would be akin to the original. Use the given boxes coordinates
                # to create the bounding rectangles. Then, save it as "imgName.mask.png"
                createMask(im, imgName, boxes)
                cv2.imwrite(outfile, im)

                print("DONE! ")
                cntGood +=1
            except:
                cntBad +=1
                print("cannot create thumbnail for {}".format(infile))

            print("----------------------------------") 
            
        print("======> SUMMARY: Processed successfully: {:d} files and unsuccessfully: {:d} files.".format(cntGood, cntBad))


    def displayResizedImagesAndBoxes(self, imgName):

        boxes = self.allImages.getBoxes(imgName)
        resized_img = Constants.resized_images_root + imgName + ".jpg"
        orig_img =  Constants.orig_images_root + imgName + ".jpg"

        orig_ht, orig_wd, orig_depth = plt.imread(orig_img).shape

        dpi = 80
        im_data = plt.imread(resized_img)
        height, width, depth = im_data.shape

        # What size does the figure need to be in inches to fit the image?
        figsize = width / float(dpi), height / float(dpi)

        # Create a figure of the right size with one axes that takes up the full figure
        fig = plt.figure(figsize=figsize)
        ax = fig.add_axes([0, 0, 1, 1])

        # create bounding boxes for the QR codes
        print("=======> BOXES FOUND: {:d}".format(len(boxes)));
        for box in boxes:
            xy,wd,ht = box.evalPatchParams(orig_ht, height, orig_wd, width)
            rect = patches.Rectangle(xy,wd,ht,linewidth=1,edgecolor='r',facecolor='none')
            print("adding rectangle at: {}, with width: {} and ht: {}".format(xy[0], xy[1], wd, ht))
            ax.add_patch(rect)

        # Hide spines, ticks, etc.
        ax.axis('off')

        # Display the image.
        ax.imshow(im_data, cmap='gray')

        plt.show()

# %%
processor = ImageProcessor()

# %%
processor.processImages()
# Out:
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3L2IS5HSFAI8AMQTSY1BSPC3D78UNB-A22ZV1G6YEIK89-hit.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3TEM0PF1Q5XJ8ON05X9O7DC2JE1D08-AKP3UXJ0TDPVO-ABCscan.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3C6FJU71TQT2MLU7Z0AM95AAHSPUYG-A1CNITFHQHCTZ1-53774228473__B13613D7-DBC1-4670-95BB-4B3091A7AB2A.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3AMYWKA6YBM5QW04XV3LR8YS0W96OG-A3D4YRQRF43YPL-MTURK_0115181449_HDR.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3LO69W1SU3DZH4MDWGWFBI7NZ4UGLW-A1640H4RXH8NZE-IMG_20180114_203513.jpg
# boxes found: 5
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3N2BF7Y2VQUXNIZ9GYFCWVYDE9WHMX-A1OZ5BB2L44KG-3AB625EA-A6F7-4DEC-9915-1C868EDA67FB.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-33FBRBDW6OZRLLMP05RSGM02HC1C8U-A20DA3UPHPQSST-mturk photo form.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3PPTZCWALQKAZIXVEDS0DBMNK1TQZ4-AL6SSBKPLSYCR-image1.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-37W3JXSD668FEPJCU0PNRTV727VWYA-AL7DCS6TQTSI8-doc15012018.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3A7Y0R2P2OO480T3I5K6JPUQY88JXI-A108BWNVR0JVJ7-scan0023.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3YGXWBAF70HQ2KZNO21FZAKXFQ64CG-A1051DBTLWP5A2-AmazonMTurk.jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3WAKVUDHUWGJ71Y6CRKMWSQDDS4U71-A2A09MMZTF07B3-20180114_220559.jpg
# boxes found: 1
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3KIBXJ1WD5UCPBLTZZXM1R3A1QLKOP-A3PZFH5OCGESG3-MTurk Handwritten.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3CPLWGV3MOZAQU2QUN6KWTPP0M4N9J-A26ZXP45O8JIXZ-IMG_2581.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3AQF3RZ558IBKJNBYSKV4EPE8U46FE-A1UOPV3DJ85ZMU-IMG.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-33CKWXB73JKPNIS6LNTTKGU3Z9F11K-A3KOXHH84OKZ9G-A3KOXHH84OKZ9G.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OWEPKL089C6CBEXFQ80IXYJ5XZ7NC-A1NSHNH3MNFRGW-characters.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3RJSC4XJ10UO4B87QRR591OA6X305N-ARN7UD2AVGF3Y-image1-2.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3E7TUJ2EGCM14IBD5TSH0ODVMI5D9U-A2S70WW1VAPKK8-IMG_9116.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3IO1LGZLK9X254DOQEEPUM8SLRA68I-A2I80SIT0763QG-CCI15012018_3.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3L70J4KAZGMF91LIXZ6HWJOFS0LDA7-A1BJNNFHK6J1ED-20180115_083519.jpg
# boxes found: 5
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3ZWFC4W1UU7462LVQGNTF9GA4HGRFV-A2LV5432PV1S39-A2LV5432PV1S39.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3R08VXYT7CVWZ5NB7RZNEGBAY8LW78-A37WNAUB0HD3O3-MturkHandwritting.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3I3WADAZ9Q497S0QSCTGZ2KS40T5OS-A126IXCDI696D7-HRS.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3SNVL38CI4SBGMOQ9UOV6R9TCC4KCU-A25NI7DEN0IDCI-doc03458420180115111511.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OUYGIZWR7YSXLQQA60J77TRXX8P02-AR8OI4XJ0E7AI-26913453_1590321191049516_1881061000_n.jpg
# boxes found: 1
# cannot create thumbnail for /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OUYGIZWR7YSXLQQA60J77TRXX8P02-AR8OI4XJ0E7AI-26913453_1590321191049516_1881061000_n.jpg
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-38F71OA9GTWD9M83L8RCTAM0YVWFMC-A1NYI79LUIBOTP-IMG_1154.jpg
# boxes found: 3
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-32N49TQG3GI13IL4OK6B25UMS7RVAQ-A2OKXW8OUFQF3E-characters.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3TOK3KHVJTIOUWE9G58DXMYOV6G7O1-A11IE8FR0MCIF-IMG_20180114_205426.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-32KTQ2V7RDF48CHQIMRKJE0PVWUM9I-A175PJR0W3LO8I-Alphabet.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-35K3O9HUABDFXYGQ4A3TG2HRPS2FEI-A2IDOTU51N1TRD-turk handwriting.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3JNQLM5FT4M92AE6X1BQ9EDMPLXL2Q-A1I6LWJWGKXOUU-handwriting.jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3R3YRB5GRF31Q3W4JUW66JS3E1WUAG-A2I1IBMQ1J82J9-IMG_20180115_222229293 (1).jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3IHR8NYAM719W98RT7NLJAJ4E9QP4K-A215U3DIT24TIL-scan.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OVHNO1VE61GA9TQ9RMGDCFO1LLZDN-AIFSTYKUQOXQD-mt.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3L0KT67Y8EGM7823AVFMU4SMWURYSP-AO83CM9S0J94D-IMG_20180114_205333593.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3DH6GAKTYYPJ8KOH5N9UQXPPJ9SZYW-A2QFPTDHTGPSGB-New Doc 2018-01-14.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3YGXWBAF70HQ2KZNO21FZAKXFRLC45-AN3NWLA2FK7OB-murk handwriting.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-35GCEFQ6I5OISHRTG2G403TCABG3ZJ-A3NE6ZRQJP7X2Q-27016363_10214140070643474_1711531278_o.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-35USIKEBNRGN8B0SWG38CJYNAM36N0-A38A1U3DJ0KLUQ-handwritten.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-333U7HK6I9FQAUOMR5JUPIRYIN7DJF-A1SCDQLN07S9Y2-IMG_0294.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-35USIKEBNRGN8B0SWG38CJYNALVN67-A290ERYABTGYDS-IMG_20180115_094640.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3RSDURM96AMLXPXL90VH5NO7V3OYEU-AOSB3RSWQQENC-hit 002.jpg
# boxes found: 3
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-33FBRBDW6OZRLLMP05RSGM02HD5C80-A21LB023L14XC1-MTurk Handwritting.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3DL65MZB8DF8UMWGD8DS8WWOSFZECV-A52KLJ02CWEK3-IMG-1408.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-32SCWG5HIH4NBWC5CVG0G83IA0SP61-A2AE187YCSLJ1Y-IMG_6681.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-31Q0U3WYDPF3Y478A3A2LQLG2WJ17N-ADHGRKTV49GLP-20180115_155829.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3DL65MZB8DF8UMWGD8DS8WWOSG3CEZ-A1E7FW7MBG7I01-20180116_043100.jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3ZPBJO59KP1UJOTW35G9D5BJ5VEDHL-A2WI07E5TKIBJH-IMG_5958.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3JBT3HLQF82PZ6WGE0DBD6WDF4NPZQ-ANN162CY5IAGN-P_20180115_074241.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3GLB5JMZFXVGJSYLJZYRS5ZIQV0DGL-A3L29NZWGZ9CFH-mturks.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-34T446B1C0E93WHM51EDN7UKYEWC0E-AGTKQI9PCODC5-IMG_7929.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3BXQMRHWKZY2S45TGXMBFAN38IMMUT-A2XM4S4D6OZ7JK-20180115_224925.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3YDGXNSEOZUOQH9A7QLAXOOEP0M48D-AKHO08K69B4Y4-amazon.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OVR4I9USPJUWL96TK2AJF9EJ5C4QQ-AWCXMFOESM9RO-20180114_233605.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3XCC1ODXDLB1XRB44WYNR8KOBJ0RQ0-A1ZUK2D4LKW4PU-Image.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-382M9COHEHF4GGDGZZYS22IUZFIUEX-A1XNHULZILJ3G3-2018-01-15 13.02.15.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3HOSI13XHZOD78OUH9XJMKWLD4ODDH-A1HDD2B9I6D33I-manual.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3L4D84MILZS7MATOD12KG36WAGFJHB-A6JFRB432NWIX-MTURK.jpg
# boxes found: 1
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3U088ZLJVKTIHUNRMSEEZ11NQUEW07-A1R7TK9LKSM72O-img001.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3K772S5NP8BZBU7WZ0RTJNT457AEHA-A1VAGO1PMX7DS3-IMG_20180115_130444.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3VD82FOHKQOU6D957MGOD8Q2WIJCOD-A39557MOQ3IY7U-form.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-374TNBHA8BVAUSNQIRQHZ4DLE6CYQ6-A27LR932J8F67W-20180115084614.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3H7XDTSHKCRFSYYC0U3HKTO3XB4WGB-A3KP9S4UQUKR5N-IMG_1211.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3EF8EXOTT1VWIZ8ABCZZOGQPTQB1JK-A302512CBCH9X2-IMAG0001.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3C5W7UE9CFQU98ZOL2XYZHM72ZGMXW-A2DABB2TUS8ZDH-image.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-37XITHEISW9X3Q1LZEXS73V774RRCN-A13B56UPRDS9HH-2018-01-14 22.05.10.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-33NF62TLXJ2YO0UWJM5HTVMO2X2KJZ-A3FW9NWR6TJ4M9-mtruk doc.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3GS6S824SQXL2QFYNYGCADX0YOQWNL-A18WPTVQPM9LBH-IMG_1512.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-30IQTZXKAK6X6USHWXA01KFUZX00XM-AAR9DD8FEW7DN-mturk_1.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3ZAK8W07I4E5PQYMRSZDHDGQ5E1U04-A17UTAVQMEF94Z-IMG_20180115_103112.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-39LNWE0K4UWGWLF2VIOJNHGMR8NUI4-A3KQC9CP3FDYSO-IMG_0761.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3Z4AIRP3C6DXDJDZSGE0FPY44OSX16-A3SUHO064258EB-20180115_155503[1].jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3C2NJ6JBKAHZQAHR9ER5M6HBUGNN2K-AY4B7SUM68J3G-Photo on 1-14-18 at 5.33 PM.jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3I7DHKZYGN0F1FNXT9AQC8BEC07F5N-A2Q5611EAZIMK2-Handwritten Characters.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-30BXRYBRP4XTSUTNK0LZ5T04CB8WH1-ACSS93E03ZUGX-mturkhandwriting.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3BV8HQ2ZZW1GOS63NCY3QDENBEW6A6-A2X2NJ5MCVJCLW-001 (2).jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3CFJTT4SXTQEYA36IAV8DP22JXN7IC-A2FW27RNKPQT0Y-IMG_4907.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3F6KKYWMNB1MTKF763BMIP8FR8VDN4-A2VHPCRLEIWL9L-20180115_181432.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3TGOYF991XML5CA2PZDX6K4XL4FUUJ-A3PTY2GRDKPF4B-1.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3TAYZSBPLL8W6N9WHA8RL0RHHFVS21-A2ITS34MWXCE0N-IMG_20180114_192028093.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-37TD41K0AH99451YE3XXXD03T6JCS5-A220WW3GUXWDTI-20180115_113807.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3PJ71Z61R427CNV1P08MZMCMXLY91W-A3BXWH8UBS36AX-form (2).jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3S4AW7T80BIJ5OTT1FUE2TAK9ZS4L4-A1160COTUR26JZ-20180115_083532.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OSWBBLG1EXR5ETB89YVGRZDTMXDXG-A241PV6A122I5X-IMG_3648.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3K5TEWLKGVBG904208YOJ3I55FOVIM-A1JLQNPXN3NHVP-pic2.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3VHP9MDGRNK000WC8JXYQEHO4GECFB-A31CYXT7WHIG2B-alphabet.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3W92K5RLWUH4XC9NTOFUUUE00UU5V0-A2XGXUHV84H2I6-turkimage.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3JWH6J9I9SDTENHNS7KGNZKFOM8NBU-A26ZP1JDV9TH03-Mturk.jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3HL8HNGX451Y22P9WZN7OOGGYVBF9X-A12LTN5SCUBIHY-WhatsApp Image 2018-01-14 at 6.39.40 PM.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-352YTHGROVDHJSA3AUFGA1HDSJKH4D-A1KTWI1LR103R0-Scan_20180116 (2).jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3PXX5PX6LXYMU4NYJ3FB1T0FPGNABD-A3RQ8P5ZR31BCI-20180115_200013.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3KGTPGBS6XLCL0106F3R01952CO2UZ-A35TTZLWEA1OOF-CCI15012018.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-345LHZDEDXS16IXJAFHWJBEX8QSU36-A2HDAMTBOMQ32-2.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-326O153BMIYIZE2UD483S2E6DFBDEU-A3G9I5FL8DWSMO-20180114_182906.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3VELCLL3GKJGDXMESM8E9IYX0KB1F0-AOZAAHRSY26FI-mturk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-35LDD5557A4OP80HMJI99NE56Q8KMC-A18MIOZ2MS4YUB-IMG_20180115_154123.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3MYYFCXHJ373JWFSQOXYP15CDJCG4I-A11X67ZZS62IIT-IMG_5443.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-34BBWHLWHABTOP47QI3K551JCOTIWM-A2K3MYD0NB9Z3P-turksample.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3L2IS5HSFAI8AMQTSY1BSPC3D8IUNN-A329JQGEQDGA5N-mturk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-326O153BMIYIZE2UD483S2E6DFBDEU-A3G9I5FL8DWSMO-20180114_182906 (2).jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3WYGZ5XF3WFRN3DM6GEVLWDBYGWSK4-A1JQZLDXTQ99VL-alphabet turk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3S4AW7T80BIJ5OTT1FUE2TAK90I4LW-AS0QXP8RRVC05-Handwritten_Scan.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3L0KT67Y8EGM7823AVFMU4SMWUVYST-A2Y8H19KDBK3GK-Handwriting Mechanical.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-337RC3OW052IZ1C8LBV1BJAXMJOLVW-A13ZNIEXIJ66U1-103_0009.jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-30BXRYBRP4XTSUTNK0LZ5T04CBHWHA-A3BPRPN10HJD4B-20180115_092144.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3E7TUJ2EGCM14IBD5TSH0ODVMJX9DK-A28W7USM54QQKW-VIMAL MTURK.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3ZQIG0FLQEGYAVO7PP23KURDKRYWV8-AILDNTO2TWB4A-mturkcharactersample.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OONKJ5DKCJBW8HZTMKT2OKKEWFBOZ-A2EJLKLPXT8GDI-20180115_114342.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3BWI6RSP7G92I51KMR5HSA4AR487EV-A3SX229VS1X6B6-IMG-0096.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3GDTJDAPVUB4U7YGDUL6JI5EBQF8MI-A2NA3O1SF7SQPF-qwc.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3PDJHANYK5GVYFEHTI8V7Z1RO9MH6S-A18J7H2QA7UQIR-IMG_20180115_131849.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-37M28K1J0QDSCNLA7VSSZHJSXKBAJB-A2TMP60L81GI71-MARIACHI20180114_19424337.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3E337GFOL98P54PY8TCUOABC4ZTNG4-A2L1STH1NHJR53-20180114_184513.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3U0SRXB7CD5GUUYCO466NEPJ69HRNJ-A1USNVXB24PIAY-IMG_0533.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3RXCAC0YIRP42X2U2RNB6DLHF57G8O-A1YBS8FSUNNPHU-mturkhandwriting.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3HMIGG0U4L64OONUWX9HDDSLK0N8Y2-A302YRPIXI7P41-2018-01-14 22.42.27-2.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-37WLF8U1WPQM05FPZ3BSKRHJGR4K6F-A2LHZSD1T2HJMI-Mechanical Turk Written Character Sample.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3QAPZX2QN4DW5EPK88P7BULYMNK20W-A17V4GTPOBWJPL-IMG_20180115_081259_1.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3EO896NRAWVXRJKJDVJ9UM9KLAHJTS-A205KG21JAX553-IMG_3552.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3M68NM076H78N9SKPNKPL33XBIK6RE-A354A21I89CLEY-scan0015.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3DUZQ9U6SMO53E7Y5KS2N5OSEDUSVF-A3AQQ2W05K058D-P_20180115_105310_p.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3FFJ6VRIL1O0GZ3MXBAZYASFBKN0ID-AX1TPMK2IDHLT-Handwriting.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3IUZPWIU1O7KUKUVQLOWILGW4SLWKE-A33B85TN97HQ33-handwritten sample.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-35L9RVQFCOIG0Q4IP06YN5F7RVZUH2-A21HZ7Z9934ZNF-IMG_20180114_180209.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-336YQZE83VEL7PFEFWE37YVN9045M3-ABXQIS3HYN5QG-MTurk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3UWN2HHPUY5SV9YP3T6BDOUFSASSNY-A1EDHCVA75M8WZ-new doc 2018-01-15 15.52.35_1.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3BWI6RSP7G92I51KMR5HSA4AR7T7EM-AZWJ8K8M2UX1M-20180117_140047.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3FE2ERCCZX8D02I9CR2UX8P9V35OPE-A2Z1HRXP6G3WL-handwritten.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3U5JL4WY5K9E5IAIFYX2DN57G97X4Q-A205N2LYF7T1LM-IMG_1633.jpg
# boxes found: 5
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-34MAJL3QP4N2PK34V9QE67G39EL43C-A12C01LD8TO3Y8-PicsArt_01-15-11.48.55.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-32N49TQG3GI13IL4OK6B25UMSA1VA6-A20YGFCRNDTD6-IMAG2667 (1).jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3WJ1OXY92AG3S6PRGRV1ARAEH9HA8R-A2ZWTKDJRPBX0S-20180114_164305.jpg
# boxes found: 1
# cannot create thumbnail for /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3WJ1OXY92AG3S6PRGRV1ARAEH9HA8R-A2ZWTKDJRPBX0S-20180114_164305.jpg
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3I2PTA7R3TUFANY9ECPQQWYAGRYQKY-A3PF5V3YCUINDY-20180114_185827.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-30OG32W0SUBRLQT72YM6O7Q0RKMENO-A2JIHS7MHTVF7G-A2JIHS7MHTVF7G.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3VZLGYJEYLAU8FY70RNS7JIGH4UZXO-AKKJ4RED4HHR2-mturkform.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-369J354OFDAHYJJ69CQDMZPQ994G6N-A2YB684AX4TXD6-20180114_163927~2.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-32Q90QCQ1SLQDK845LUQWF9WXO9EK9-AI46QXF9WCXNB-0114181931b.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-373ERPL3YO8EP73WL0SIWDVBVQ1TRI-ANUG05IDFTWF-IMG_0263[1].jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-30X31N5D63QLBQ40UP16RIAFT41SAO-AJ88E0PWT78WZ-20180115121418433.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3E13VNJ1NNV0NOO4TUEZCFBPGCT1IH-A1PYZX3R89GXWB-20180115_143901.jpg
# boxes found: 5
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3EJJQNKU9R5OKYC1L6BTIUSNKW1RH1-A1NITBXDX8TN7T-IMG-2884.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3ZAZR5XV01I65HNC9VR5T6X6GLHZCV-A8LE6KEX6L5N7-IMG_1300.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3AAJC4I4FGSTDVTIJN8RGAA166XZJI-A3NIYTQL24PSND-20180115_173956.jpg
# boxes found: 1
# cannot create thumbnail for /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3AAJC4I4FGSTDVTIJN8RGAA166XZJI-A3NIYTQL24PSND-20180115_173956.jpg
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3M81GAB8A0JEHKUF8ZCXRTFKTXNQBC-A36PRTZFECB76C-IMG_3154.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3SBEHTYCWN3XDUZ75JL8Q2MZNWVIYN-A2CX2ALCXU9HW0-IMG_20180115_090656644.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3QY5DC2MXRKWMUDCUAIYKK3UBGRUF9-A32XODQOC2CCDG-Turk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-35GMH2SV3EH93BTJ3DMJ3WQ5HU4EOG-AUX7UUYV8C9WY-Scan_20180115.jpg
# boxes found: 3
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3VD82FOHKQOU6D957MGOD8Q2WIJOCP-A1KAIOBTXQ77A6-20180115_130527_001.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3N2BF7Y2VQUXNIZ9GYFCWVYDE9WHMX-A1OZ5BB2L44KG-hit.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OJSZ2ATDSW2MM8RBQCEOGYXEBA57T-A2MTTS331O7Y1T-mturk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-31Q0U3WYDPF3Y478A3A2LQLG2WM71W-A3F1ESQELWVGCE-Scan 1.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3IFS6Q0HJIJ0H8NY6DTJ8GYY6C8ISK-A3HUQ8WJCD1YM3-15160570359021116371837.jpg
# boxes found: 1
# cannot create thumbnail for /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3IFS6Q0HJIJ0H8NY6DTJ8GYY6C8ISK-A3HUQ8WJCD1YM3-15160570359021116371837.jpg
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3JWH6J9I9SDTENHNS7KGNZKFONFNB3-A1PNVYCV1ND3IB-ABCMturk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3EA3QWIZ4IV1W80DVDY9ILUK8UFIT0-ALT86ZCKZZMLZ-handwriting sample.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3Y54SXRO1LL65ZVDPUNN1OIV2PVTUC-A3UBAGF1HZO7O2-Jeffrey Lee MTURK hit.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3OONKJ5DKCJBW8HZTMKT2OKKEZRBOH-A1IXQ8X3QKLR6K-character samples.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-32EYX73OY09TPKILL5IS19HDE5IRUJ-A2W2LPDYFW2032-8E94ADA7-EAD2-4D9C-BA77-7D2F37D19D1C.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-33LK57MYLT5MCYC86HH58B1O2Q8SZR-A31RPRVAR1ZQYM-handwriting.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3U4J9857OEB4B2P0C03RR2YPO7WB70-A34KY2J63KLF7K-Amazon.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3QIYRE09Y3HS1PZVQARRHN762AC1NK-A2YZOLQG0GSJCR-IMG_1884.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3QILPRALQ5VACPJGPV06WXUEGGI8NB-ASN25PIODXIPJ-20180114_220549.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3FUI0JHJPXYH7OK0VVLVW2OXVGH33M-A3T4SWIVIT1M8T-IMG_20180117_0001 (1).jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-352YTHGROVDHJSA3AUFGA1HDSII4HW-A6BFUP70ZGV1Y-MTurk22.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3Z7EFSHGN9EH0MNX8D3KWLHV8MXCXR-A3S5GYPFOGMV0C-SKM_4050180115205300.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-388U7OUMF71D9Y65NY48C2T6YG70RI-A24YT6TB7HLM5G-Mturk1.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3B3WTRP3DB2E18DX848045MRPR6290-A1ZB9NXFDNCH55-20180114_181057.jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3WT783CTPBHANJKW3HB27OQ3PK1CBC-A60WUDYUFK0YF-20180116101733053.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-39LNWE0K4UWGWLF2VIOJNHGMR8MIUR-AJNQ2PBD07FKE-turk write.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3PH3VY7DJLXFJFTHQMR6504982VWZZ-AIAWJKOKMOM0-IMG_20180116_112044.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3300DTYQT2HCON6ZIQENS1L5WU2QEE-A1HJXVLKS5OIZU-20180114_203442.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3ZWFC4W1UU7462LVQGNTF9GA4IXFR2-A31Q4HFUPE2DXG-01301000.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3SITXWYCNV9YQHVRUD7PL1BDQ09XBF-A39ZYRK3XFFUBJ-IMG_20180114_161720286.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3WR9XG3T63BKQ34RXLT4JOSJEGO741-A26OCSX1VUO9EV-001.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3X66WABAJWII10WOQASFFWD6ZJG3GK-A1NKAIWOGR30X4-handwriting .jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3QXNC7EIPIV75YAJTH4MLHTCSU1904-AQ9MN0X9EEKJX-3QXNC7EIPIV75YAJTH4MLHTCSU1904.jpg
# boxes found: 1
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3CFJTT4SXTQEYA36IAV8DP22JXS7IH-AP34EG7NEQMG6-IMG_0496.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3JNQLM5FT4M92AE6X1BQ9EDMPLVL2O-ADAJM2AFAB56T-IMG_0049.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3TK8OJTYM1L8QMR6D3O8S0JHRTIVPX-A2U9BUQBGNBVI5-2018-01-14_19-19-44_095.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3FTYUGLFSULI3V9123F0O88T0MN5DW-A1RKY6QL7SFX5K-IMG_20180115_090608564.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3P59JYT76LKXLNMB6ADHV5N3JZOT28-A1Z04QM6PAIK13-img20180115_13360205.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3QAVNHZ3EM4Y7D9AAG45FWWK1AVALU-A154EGPMXIJI3X-TurkHandwriting-0.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-36W0OB37HWEXMPYSVN564XUMTESHZU-A3ACPO8FK04F7O-IMG_1421.jpg
# boxes found: 3
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-35GCEFQ6I5OISHRTG2G403TCA87Z30-ANSSUNQ53WEUM-scan0306.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3907X2AHF05ZTVT4PT4XQVM6UVQ2PX-A1WLQAGAFA20CB-alpha.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-37U1UTWH9VMVRNB8I2HN5HZOHEK8RE-A3IAXQT58ZC4MD-Scanned from a Xerox Multifunction Printer.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3SKRO2GZ71RRTJESTXZBPVQ28FF1KN-A18KNIT4S4SOLL-20180115_125010.jpg
# boxes found: 4
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-304SM51WA34QU09S0312MTULBMMSBJ-A2XYS5D2RGWPUF-img-115162559-0001.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3AMW0RGHOD2VIHIXBC2HIJP45QPPNJ-A7R1OLLU1Z6RA-2018-01-15 12.00.35.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3MRNMEIQW56W5KCMUQV75X4QMDODLV-A27LLCYAALH73F-mturk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3NGI5ARFTT5S4AB86P4JLCC12PA1PD-AT8Y4JPJVTJSO-002.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3ND9UOO81K2VEQCDBL0XXLTBTSRLW7-A1506T1PAYRT16-Scan0006.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3UWN2HHPUY5SV9YP3T6BDOUFSB1NS4-A3QSQNAM045D3R-unnamed (1).jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3TXMY6UCAEOXRPMLMZ8S2DL2BJ4CQO-A2PWE9TKEM99BA-mTurk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3YMU66OBIN8XV83N5VHHJQEGINOHGT-A70L26UXLTGLC-Scan0001.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3QL2OFSM96ICOS9T67GBYJQX679NC2-A2JHF7CU91EVXW-IMG_5720.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# skipping image: 3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-31LVTDXBL7AQ6UVRCRQRAMLU1EARLA-A1RONKQENYQOAJ-EscÃ¡ner_20180116 because ZERO boxes were found
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3IXEICO792JL3O5CTCPKLI4FZ3IT6F-A2RR04JS69Z5LE-mturk0013.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3A7Y0R2P2OO480T3I5K6JPUQY60JX6-A4OH6BBP53XRM-IMG_5427.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3ERET4BTVM99IOHNXAE4418L6UD9KK-A3N4GQHS9E2PM1-2519_001 (1).jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-33C7UALJVLY7YICRK828ZQHBDFG18Z-AIJ8R7I080FAX-MTurk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3PH3VY7DJLXFJFTHQMR6504981SZWX-A356O3RJYQUW5M-mturk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3TPWUS5F8912BMI7Y87YU23OZJACWF-A1W4UH23PJ33GT-MTurk.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3TYCR1GOTCJZ8LHIM8K4WPNTAUMLZO-AK9XE112RZO6Q-FullSizeRender.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3NC5L260MOM19PTFYO6PLEB5TU3OFQ-A11MKBA5X9ADL5-Image.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3IQ1VMJRYTK36B81LJ1FAN5P1GXA9G-A37AUN0IO1OLES-New Doc 2018-01-16_1.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3KV0LJBBH2LACCDCC3R6AZ0J1IUMRZ-A3ERAC9ADCIAOW-image_123923953.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3A7Y0R2P2OO480T3I5K6JPUQY5SXJA-A2BI8BZTDSLX6H-IMG_8652.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# processing file: /home/apil/data/hw_forms/initial_data/s3_upload1/3ZQA3IO31AQ7WQ1D1NM28SCN43U1O6-3JC6VJ2SABJK5O6PITOYY70NFJM5AQ-A1SR8FKTE4QVOX-Mechanical turk - Handwritten Character Sample.jpg
# boxes found: 6
# DONE!
# ----------------------------------
# ======> SUMMARY: Processed successfully: 204 files and unsuccessfully: 5 files.
